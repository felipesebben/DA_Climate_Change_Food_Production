# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
annual_temp = 'https://pkgstore.datahub.io/core/global-temp/annual_csv/data/a26b154688b061cdd04f1df36e4408be/annual_csv.csv'

# %%
df_global_temp = pd.read_csv(annual_temp)

# %%
df_global_temp.head()
# Out:
#     Source  Year    Mean
# 0     GCAG  2016  0.9363
# 1  GISTEMP  2016  0.9900
# 2     GCAG  2015  0.8998
# 3  GISTEMP  2015  0.8700
# 4     GCAG  2014  0.7408

# %%
df_global_temp = df_global_temp[df_global_temp['Source'] == 'GISTEMP'].reset_index()[["Source", "Year", "Mean"]]
print(df_global_temp.head())
# Out:
#     Source  Year  Mean
# 0  GISTEMP  2016  0.99
# 1  GISTEMP  2015  0.87
# 2  GISTEMP  2014  0.74
# 3  GISTEMP  2013  0.65
# 4  GISTEMP  2012  0.63

# %%
import seaborn as sns
sns.set()
sns.lineplot(df_global_temp['Year'],df_global_temp['Mean'])
plt.ylabel("Mean")
plt.xlabel("Average Global Mean Temperature")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'Average Global Mean Temperature')

# %%
df_rice = pd.read_csv('C://Users//felip//OneDrive//Documentos//Data Analysis Projects//Climate Change//rice-yields.csv')

# %%
df_rice.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1961
# 1  Afghanistan  AFG  1962
# 2  Afghanistan  AFG  1963
# 3  Afghanistan  AFG  1964
# 4  Afghanistan  AFG  1965
#
#    Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha
# 0                                             1.0831
# 1                                             1.0480
# 2                                             0.9548
# 3                                             1.0461
# 4                                             1.0621

# %%
import csv
HEADERS = next(csv.reader(open('C://Users//felip//OneDrive//Documentos//Data Analysis Projects//Climate Change//rice-yields.csv')))
print (HEADERS)
# Out:
# ['Entity', 'Code', 'Year', 'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha']

# %%
from collections import Counter
print(set(df_rice['Entity'].values))
print("NUMBER OF REGIONS: ", len(set(df_rice['Entity'].values)))
# Out:
# {'Nepal', 'Comoros', 'Trinidad and Tobago', 'India', 'Kenya', 'North Macedonia', 'Belgium-Luxembourg', 'Austria', 'China', 'European Union', 'Norway', 'Bolivia', 'Finland', 'Iran', 'Turkey', 'Syria', 'Asia, Central', 'Morocco', 'El Salvador', 'Montenegro', 'Jamaica', 'Yugoslavia', 'Libya', 'Azerbaijan', 'Barbados', 'Saint Vincent and the Grenadines', 'Guadeloupe', 'Angola', 'Australia', 'Reunion', 'Sudan (former)', 'Eritrea', 'Cape Verde', 'Eswatini', 'Czechia', 'Haiti', 'Kuwait', 'Gambia', 'Northern America', 'South Sudan', 'Yemen', 'Southern Europe', 'Guinea-Bissau', 'Western Asia', 'Croatia', 'Bulgaria', 'Dominica', 'Tunisia', 'Ethiopia', 'Qatar', 'Western Africa', 'Eastern Europe', 'Djibouti', 'Guyana', 'French Guiana', 'New Caledonia', 'Sri Lanka', 'Timor', 'Malaysia', 'USSR', 'Afghanistan', 'Canada', 'Pacific Islands Trust Territory', 'South Africa', 'Japan', 'Maldives', 'Middle Africa', 'Hungary', 'Ghana', 'Philippines', 'Uruguay', 'Honduras', 'Northern Africa', 'Southern Asia
# ...

# %%
df_rice = pd.read_csv('C://Users//felip//OneDrive//Documentos//Data Analysis Projects//Climate Change//rice-yields.csv')
df_rice = df_rice[df_rice['Entity']=='Nigeria'].reset_index()[["Entity", "Code", "Year", 'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha']]
df_rice.rename(columns={'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha':' (tonnes per hectare)'}, inplace=True)
print(df_rice.head())
# Out:
#     Entity Code  Year   (tonnes per hectare)
# 0  Nigeria  NGA  1961                 0.7388
# 1  Nigeria  NGA  1962                 0.7747
# 2  Nigeria  NGA  1963                 0.7577
# 3  Nigeria  NGA  1964                 0.7113
# 4  Nigeria  NGA  1965                 0.6808

# %%
sns.lineplot(df_rice['Year'], df_rice[' (tonnes per hectare)'])
plt.ylabel("Rice Production in Nigeria (tonnes per hectare)")
plt.title("Annual Rice production in Nigeria")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Annual Rice production in Nigeria')

# %%
sns.set()
sns.lineplot(df_global_temp['Year'], df_global_temp['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and rice production in Nigeria")

sns.lineplot(df_rice['Year'], df_rice[' (tonnes per hectare)'])
plt.ylabel("Mean temperature/tonnes per hectare rice in Nigeria ")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean temperature/tonnes per hectare rice in Nigeria ')

# %%
df_rice = pd.read_csv('C://Users//felip//OneDrive//Documentos//Data Analysis Projects//Climate Change//rice-yields.csv')
df_rice.rename(columns={'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha':' (tonnes per hectare)'}, inplace=True)

df_rice = df_rice[df_rice['Entity']=='Haiti'].reset_index()[["Entity", "Code", "Year", ' (tonnes per hectare)']]
print(df_rice.head())
# Out:
#   Entity Code  Year   (tonnes per hectare)
# 0  Haiti  HTI  1961                 0.9905
# 1  Haiti  HTI  1962                 0.9989
# 2  Haiti  HTI  1963                 1.0081
# 3  Haiti  HTI  1964                 1.0073
# 4  Haiti  HTI  1965                 1.0196

# %%
sns.lineplot(df_rice['Year'], df_rice[' (tonnes per hectare)'])
plt.ylabel("Rice Production in Haiti (tonnes per hectare)")
plt.title("Annual Rice production in Haiti")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Annual Rice production in Haiti')

# %%
sns.set()
sns.lineplot(df_global_temp['Year'], df_global_temp['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and rice production in Haiti")

sns.lineplot(df_rice['Year'], df_rice[' (tonnes per hectare)'])
plt.ylabel("Mean temperature/tonnes per hectare rice in Haiti ")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean temperature/tonnes per hectare rice in Haiti ')

# %%
df_agricultural_land = pd.read_csv('C://Users//felip//OneDrive//Documentos//Data Analysis Projects//Climate Change//agricultural-area-per-capita.csv')
df_agricultural_land.head()
# Out:
#         Entity Code  Year  agricultural_land_per_capita
# 0  Afghanistan  AFG  1961                      4.111497
# 1  Afghanistan  AFG  1962                      4.037880
# 2  Afghanistan  AFG  1963                      3.961981
# 3  Afghanistan  AFG  1964                      3.886491
# 4  Afghanistan  AFG  1965                      3.804116

# %%
print(set(df_agricultural_land['Entity'].values))
print("NUMBER OF REGIONS: ", len(set(df_agricultural_land['Entity'].values)))
# Out:
# {'Nepal', 'Comoros', 'Trinidad and Tobago', 'India', 'Kenya', 'North Macedonia', 'Niue', 'Cayman Islands', 'French Guyana', 'Austria', 'China', 'Norway', 'Bolivia', 'French Polynesia', 'Finland', 'Iran', 'Turkey', 'Syria', 'Morocco', 'El Salvador', 'Singapore', 'Montenegro', 'Jamaica', 'Libya', 'Azerbaijan', 'Equatorial Guinea', 'Barbados', 'Saint Vincent and the Grenadines', 'Tokelau', 'Guadeloupe', 'Angola', 'Andorra', 'Australia', 'Sudan (former)', 'Eritrea', 'Cape Verde', 'Eswatini', 'Czechia', 'Haiti', 'Kuwait', 'Gambia', 'American Samoa', 'Northern America', 'South Sudan', 'Southern Europe', 'Guinea-Bissau', 'Saint Kitts and Nevis', 'Western Asia', 'Yemen', 'Croatia', 'Nauru', 'Bulgaria', 'Dominica', 'Faroe Islands', 'Tunisia', 'Ethiopia', 'Qatar', 'Western Africa', 'Eastern Europe', 'Djibouti', 'Guyana', 'Kiribati', 'Wallis and Futuna Islands', 'New Caledonia', 'Sri Lanka', 'Timor', 'Malaysia', 'Martinique', 'USSR', 'Southeast Asia', 'Afghanistan', 'Canada', 'South Africa', 'T
# ...

# %%
df_agricultural_land = df_agricultural_land[df_agricultural_land['Entity']=='Haiti'].reset_index(drop=True)
[['Entity','Code','Year','agricultural_land_per_capita']]
print(df_agricultural_land.head())
# Out:
#   Entity Code  Year  agricultural_land_per_capita
# 0  Haiti  HTI  1961                      0.421112
# 1  Haiti  HTI  1962                      0.414264
# 2  Haiti  HTI  1963                      0.407540
# 3  Haiti  HTI  1964                      0.400944
# 4  Haiti  HTI  1965                      0.394484

# %%
sns.lineplot(df_agricultural_land['Year'], df_agricultural_land['agricultural_land_per_capita'])
plt.ylabel("Agricultural land per capita in Haiti")
plt.title("Annual variation on avaliable agricultural land in Haiti")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Annual variation on avaliable agricultural land in Haiti')

# %%
sns.set()
sns.lineplot(df_global_temp['Year'], df_global_temp['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and Avaliable Agricultural land in Haiti")

sns.lineplot(df_agricultural_land['Year'], df_agricultural_land[ 'agricultural_land_per_capita'])
plt.ylabel("Mean temperature/agricultural area per capita")
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean temperature/agricultural area per capita')
